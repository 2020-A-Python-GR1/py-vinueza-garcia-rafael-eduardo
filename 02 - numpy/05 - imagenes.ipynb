# %%
import numpy as np
from scipy import ndimage
from scipy import misc
from PIL import Image

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/2018-B-GR1-Python/python/master/Imagen%20como%20un%20arreglo.PNG "Logo Title Text 1")

# %%
mapache = misc.face()

# %%
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
import matplotlib.pyplot as plt
mapache.shape
# Out:
# (768, 1024, 3)

# %%
mapache = np.array(Image.open('./mapache.jpg'))
plt.imshow(mapache)
plt.show()

# %%
mapache = np.array(Image.open('./mapache.jpg'))
dimension = 3
tamanio_pieza_float = mapache.shape/np.array((dimension,dimension,1))
tamanio_pieza = tamanio_pieza_float.astype(np.int)

grilla = np.array([])
inicio = np.array([0,0])
fin = np.array([tamanio_pieza[0], tamanio_pieza[1]])
i = dimension
j = dimension
num = 0

pieza[num] = mapache.crop(0,0,tamanio_pieza[1],tamanio_pieza[0])

while j > 0:
    while i > 0:
        #grilla = np.append(grilla, mapache[inicio[0]:fin[0], inicio[1]:fin[1]])
        #pieza[num] = mapache.crop(0,0,inicio[0],fin[0])
        num = num + 1
        inicio[1] = inicio[1] + tamanio_pieza[1]
        fin[1] = fin[1] + tamanio_pieza[1] 
        i = i - 1
    inicio[0] = inicio[0] + tamanio_pieza[0]
    fin[0] = fin[0] + tamanio_pieza[0] 
    inicio[1] = 0
    fin[1] = tamanio_pieza[1]
    i = dimension
    j = j - 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-460a868c8ada> in <module>
#      11 num = 0
#      12
# ---> 13 pieza[num] = mapache.crop(0,0,tamanio_pieza[1],tamanio_pieza[0])
#      14
#      15 while j > 0:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'crop'

# %%
mapache = Image.open('./mapache.jpg')

pieza = mapache.crop((0,0,400,300))
pieza = mapache.crop((800,600,1200,900))
plt.imshow(pieza)
plt.show()
